# %% [markdown]
# **MODULE - 1: INTRODUCTION TO THE EXPLORATORY DATA ANALYSIS(EDA)**

# %%
# Importing the necessary libraries
import pandas as pd

# Load the dataset from the new GitHub link
url = 'https://raw.githubusercontent.com/salemprakash/EDA/main/Data/HepatitisCdata.csv?raw=true'
data = pd.read_csv(url)

data.head()
# Out:
#    Unnamed: 0       Category  Age Sex   ALB   ALP   ALT   AST   BIL    CHE  \
# 0           1  0=Blood Donor   32   m  38.5  52.5   7.7  22.1   7.5   6.93
# 1           2  0=Blood Donor   32   m  38.5  70.3  18.0  24.7   3.9  11.17
# 2           3  0=Blood Donor   32   m  46.9  74.7  36.2  52.6   6.1   8.84
# 3           4  0=Blood Donor   32   m  43.2  52.0  30.6  22.6  18.9   7.33
# 4           5  0=Blood Donor   32   m  39.2  74.1  32.6  24.8   9.6   9.15
#
#    CHOL   CREA   GGT  PROT
# 0  3.23  106.0  12.1  69.0
# 1  4.80   74.0  15.6  76.5
# 2  5.20   86.0  33.2  79.3
# 3  4.74   80.0  33.8  75.7
# 4  4.32   76.0  29.9  68.7

# %% [markdown]
# **Step 2: Explore the Dataset**

# %% [markdown]
# Dimensions of the Dataset

# %%
data.shape
# Out:
# (615, 14)

# %% [markdown]
# Summary of the Dataset

# %%
data.describe(include='all')
# Out:
#         Unnamed: 0       Category         Age  Sex         ALB         ALP  \
# count   615.000000            615  615.000000  615  614.000000  597.000000
# unique         NaN              5         NaN    2         NaN         NaN
# top            NaN  0=Blood Donor         NaN    m         NaN         NaN
# freq           NaN            533         NaN  377         NaN         NaN
# mean    308.000000            NaN   47.408130  NaN   41.620195   68.283920
# std     177.679487            NaN   10.055105  NaN    5.780629   26.028315
# min       1.000000            NaN   19.000000  NaN   14.900000   11.300000
# 25%     154.500000            NaN   39.000000  NaN   38.800000   52.500000
# 50%     308.000000            NaN   47.000000  NaN   41.950000   66.200000
# 75%     461.500000            NaN   54.000000  NaN   45.200000   80.100000
# max     615.000000            NaN   77.000000  NaN   82.200000  416.600000
#
# ...

# %% [markdown]
# Missing Values Count

# %%
data.isnull().sum()
# Out:
# Unnamed: 0     0
# Category       0
# Age            0
# Sex            0
# ALB            1
# ALP           18
# ALT            1
# AST            0
# BIL            0
# CHE            0
# CHOL          10
# CREA           0
# GGT            0
# PROT           1
# dtype: int64

# %% [markdown]
# Numerical Summary

# %%
data.describe()
# Out:
#        Unnamed: 0         Age         ALB         ALP         ALT         AST  \
# count  615.000000  615.000000  614.000000  597.000000  614.000000  615.000000
# mean   308.000000   47.408130   41.620195   68.283920   28.450814   34.786341
# std    177.679487   10.055105    5.780629   26.028315   25.469689   33.090690
# min      1.000000   19.000000   14.900000   11.300000    0.900000   10.600000
# 25%    154.500000   39.000000   38.800000   52.500000   16.400000   21.600000
# 50%    308.000000   47.000000   41.950000   66.200000   23.000000   25.900000
# 75%    461.500000   54.000000   45.200000   80.100000   33.075000   32.900000
# max    615.000000   77.000000   82.200000  416.600000  325.300000  324.000000
#
#               BIL         CHE        CHOL         CREA         GGT        PROT
# count  615.000000  615.000000  605.000000   615.000000  615.000000  614.000000
# mean    11.396748    8.196634    5.368099    81.287805   39.533171   72.044137
# ...

# %% [markdown]
# # Conclusion

# %% [markdown]
# This notebook serves as a foundational overview of the dataset, encompassing loading and initial exploration. We will dive deeper into the data through more extensive exploratory data analysis (EDA) in the upcoming modules.
